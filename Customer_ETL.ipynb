# %%
# %sql
CREATE CATALOG IF NOT EXISTS Customer; 
--CREATING A CATALOG

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS Customer.bronze;
CREATE SCHEMA IF NOT EXISTS Customer.silver;
CREATE SCHEMA IF NOT EXISTS Customer.gold;

# %%
# %sql
CREATE TABLE IF NOT EXISTS Customer.bronze.customer (
  id INT,
  name STRING,
  email STRING,
  address STRING,
  city STRING,
  state STRING,
  zip INT,
  country STRING,
  phone STRING,
  dob STRING,
  gender STRING);

# %%
# %sql
INSERT INTO Customer.bronze.customer
VALUES (1, 'John Doe', 'johndoe@example.com', '123 Main St', 'New York', 'NY', 10001, 'USA', '555-123-4567', '1990-01-01', 'Male'),
       (2, 'Jane Smith', 'janesmith@example.com', '456 Elm St', 'Los Angeles', 'CA', 90001, 'USA', '555-987-6543', '1985-05-15', 'Female'),
       (3, 'Alice Johnson', 'alicejohnson@example.com', '789 Oak St', 'Chicago', 'IL', 60601, 'USA', '555-555-5555', '1995-03-20', 'Female'),
       (4, 'Bob Brown', 'bobbrown@example.com', '321 Pine St', 'Houston', 'TX', 77001, 'USA', '555-111-1111', '1980-12-31', 'Male')

# %%
# %sql
SELECT * FROM customer.bronze.customer;

# %%
# %sql
SELECT * FROM customer.silver.customer
